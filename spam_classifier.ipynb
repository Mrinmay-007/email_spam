# %%
import pandas as pd

# %%
df = pd.read_csv('/content/spam.csv', encoding='latin1')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],inplace=True)
df
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.rename(columns={'v1':'target','v2':'text'},inplace=True)
df
# Out:
#      target                                               text
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...
# 5568    ham              Will Ì_ b going to esplanade fr home?
# 5569    ham  Pity, * was in mood for that. So...any other s...
# 5570    ham  The guy did some bitching but I acted like i'd...
# 5571    ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

encode = LabelEncoder()  # Instantiate LabelEncoder
df['target'] = encode.fit_transform(df['target'])  # Apply encoding

# %%
df
# Out:
#       target                                               text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df= df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #EDA

# %%
df
# Out:
#       target                                               text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct="%0.2f")
plt.show()

# %%
df['len_char']= df['text'].apply(len)
df
# Out:
# <ipython-input-107-caba8f802bd1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['len_char']= df['text'].apply(len)
#       target                                               text  len_char
# 0          0  Go until jurong point, crazy.. Available only ...       111
# 1          0                      Ok lar... Joking wif u oni...        29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3          0  U dun say so early hor... U c already then say...        49
# 4          0  Nah I don't think he goes to usf, he lives aro...        61
# ...      ...                                                ...       ...
# 5567       1  This is the 2nd time we have tried 2 contact u...       161
# ...

# %%
# !pip install nltk

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('punkt_tab') # Download the punkt_tab resource
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# df['word_count'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))
df['word_count'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))
# Out:
# <ipython-input-110-8b40b16dfdbc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['word_count'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
df['word_count'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))
# Out:
# <ipython-input-111-5732eae98284>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['word_count'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
df
# Out:
#       target                                               text  len_char  \
# 0          0  Go until jurong point, crazy.. Available only ...       111
# 1          0                      Ok lar... Joking wif u oni...        29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3          0  U dun say so early hor... U c already then say...        49
# 4          0  Nah I don't think he goes to usf, he lives aro...        61
# ...      ...                                                ...       ...
# 5567       1  This is the 2nd time we have tried 2 contact u...       161
# 5568       0              Will Ì_ b going to esplanade fr home?        37
# 5569       0  Pity, * was in mood for that. So...any other s...        57
# 5570       0  The guy did some bitching but I acted like i'd...       125
# 5571       0                         Rofl. Its true to its name        26
#
#       word_count
# 0             24
# 1              8
# 2             37
# ...

# %%
df['num_sentences']= df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))
# Out:
# <ipython-input-113-9a9153515e39>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_sentences']= df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  len_char  \
# 0       0  Go until jurong point, crazy.. Available only ...       111
# 1       0                      Ok lar... Joking wif u oni...        29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3       0  U dun say so early hor... U c already then say...        49
# 4       0  Nah I don't think he goes to usf, he lives aro...        61
#
#    word_count  num_sentences
# 0          24              2
# 1           8              2
# 2          37              2
# 3          13              1
# 4          15              1

# %%
df[['len_char','word_count','num_sentences']].describe()
# Out:
#           len_char   word_count  num_sentences
# count  5169.000000  5169.000000    5169.000000
# mean     78.977945    18.455794       1.965564
# std      58.236293    13.324758       1.448541
# min       2.000000     1.000000       1.000000
# 25%      36.000000     9.000000       1.000000
# 50%      60.000000    15.000000       1.000000
# 75%     117.000000    26.000000       2.000000
# max     910.000000   220.000000      38.000000

# %%
# ham
df[df['target']==0][['len_char','word_count','num_sentences']].describe()
# Out:
#           len_char   word_count  num_sentences
# count  4516.000000  4516.000000    4516.000000
# mean     70.459256    17.123782       1.820195
# std      56.358207    13.493970       1.383657
# min       2.000000     1.000000       1.000000
# 25%      34.000000     8.000000       1.000000
# 50%      52.000000    13.000000       1.000000
# 75%      90.000000    22.000000       2.000000
# max     910.000000   220.000000      38.000000

# %%
# spam
df[df['target']==1][['len_char','word_count','num_sentences']].describe()
# Out:
#          len_char  word_count  num_sentences
# count  653.000000  653.000000     653.000000
# mean   137.891271   27.667688       2.970904
# std     30.137753    7.008418       1.488425
# min     13.000000    2.000000       1.000000
# 25%    132.000000   25.000000       2.000000
# 50%    149.000000   29.000000       3.000000
# 75%    157.000000   32.000000       4.000000
# max    224.000000   46.000000       9.000000

# %%
import seaborn as sns

# %%
sns.histplot(df[df['target']==0]['len_char'])
sns.histplot(df[df['target']==1]['len_char'])
# Out:
# <Axes: xlabel='len_char', ylabel='Count'>

# %%
sns.histplot(df[df['target']==0]['word_count'])
sns.histplot(df[df['target']==1]['word_count'],color='red')
# Out:
# <Axes: xlabel='word_count', ylabel='Count'>

# %%
sns.histplot(df[df['target']==0]['num_sentences'])
sns.histplot(df[df['target']==1]['num_sentences'],color='red')
# Out:
# <Axes: xlabel='num_sentences', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
# sns.heatmap(df.corr(), annot=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame

# Select only numerical features for correlation
numerical_features = df.select_dtypes(include=['number'])

# Calculate correlation matrix
corr_matrix = numerical_features.corr()

# Generate heatmap
plt.figure(figsize=(8, 6))  # Adjust figure size if needed
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# #Data Preprocessing
# * Lowerecase
# * Remove special character
# * Remove stop word and punctuation
# * Stemming

# %%
# from nltk .corpus import stopwords
# # nltk.download('stopwords')
# stopwords.words('english')
from nltk .corpus import stopwords
import nltk
nltk.download('stopwords') # Download the stopwords data
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
# ...

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.stem.porter import PorterStemmer
ps= PorterStemmer()
ps.stem('dancing')
# Out:
# 'danc'

# %%
def transform_text(text):
  text= text.lower()
  text= nltk.word_tokenize(text)
  y=[]
  for i in text:
    if i.isalnum():
      y.append(i)
  text= y[:]
  y.clear()
  for i in text:
    if i not in stopwords.words('english') and i not in string.punctuation:
      y.append(i)
  text= y[:]
  y.clear()
  for i in text:
    y.append(ps.stem(i))
  return " ".join(y)

# %%
import webbrowser

# %%
url="https://earth.google.com/"
webbrowser.open(url)
# Out:
# False

# %% [markdown]
# # New Section

# %%
import pandas as pd

df = pd.DataFrame()

df[['City', 'Country']] = pd.DataFrame([['New York', 'USA'], ['London', 'UK'], ['Paris', 'France']])
print(df)

# Add an 'Age' column with initial values
df['Age'] = [30, 25, 40]  # Example ages

# Now you can create 'Age in 5 Years' column
df['Age in 5 Years'] = df['Age'] + 5
print(df)
# Out:
#        City Country
# 0  New York     USA
# 1    London      UK
# 2     Paris  France
#        City Country  Age  Age in 5 Years
# 0  New York     USA   30              35
# 1    London      UK   25              30
# 2     Paris  France   40              45

# %%
transform_text('HI! HOW %%aRE You??Mdas learning..%%.')
# Out:
# 'hi mda learn'

# %%
df['transform_text']=df['text'].apply(transform_text)
# Out:
# <ipython-input-130-524e99cd07c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['transform_text']=df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  len_char  \
# 0       0  Go until jurong point, crazy.. Available only ...       111
# 1       0                      Ok lar... Joking wif u oni...        29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3       0  U dun say so early hor... U c already then say...        49
# 4       0  Nah I don't think he goes to usf, he lives aro...        61
#
#    word_count  num_sentences  \
# 0          24              2
# 1           8              2
# 2          37              2
# 3          13              1
# 4          15              1
#
#                                       transform_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
from wordcloud import WordCloud
wc= WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_wc=wc.generate(df[df['target']==1]['transform_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,7))
plt.imshow(spam_wc)

# %%
ham_wc= WordCloud(width=500,height=500,min_font_size=10,background_color='white')
ham_wc.generate(df[df['target']==0]['transform_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,7))
plt.imshow(ham_wc)

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transform_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter

# %%
# sns.barplot(pd.DataFrame(Counter(spam_corpus).most_common(30))[0],pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
# plt.xticks(rotation='vertical')
# plt.show()

# %%
# Calculate word frequencies
word_counts = Counter(spam_corpus).most_common(30)

# Create a DataFrame
df_word_counts = pd.DataFrame(word_counts, columns=['word', 'frequency'])

# Create the barplot using the DataFrame
sns.barplot(x='word', y='frequency', data=df_word_counts)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # Model Buliding

# %%
# Bag of Words
from sklearn.feature_extraction.text import CountVectorizer
cv= CountVectorizer()

# %%
# x =cv.fit_transform(df['transform_text']).toarray()

# %%
# x.shape

# %%
# y =df['target'].values
# y

# %%
from sklearn.model_selection import train_test_split

# %%
# x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
# gnb.fit(x_train,y_train)
# y_pred1 = gnb.predict(x_test)
# print(accuracy_score(y_test,y_pred1))
# print(precision_score(y_test,y_pred1))
# print(confusion_matrix(y_test,y_pred1))

# %%
# mnb.fit(x_train,y_train)
# y_pred2 = mnb.predict(x_test)
# print(accuracy_score(y_test,y_pred2))
# print(precision_score(y_test,y_pred2))
# print(confusion_matrix(y_test,y_pred2))

# %% [markdown]
# * Giving Best Result

# %%
# bnb.fit(x_train,y_train)
# y_pred3 = bnb.predict(x_test)
# print(accuracy_score(y_test,y_pred3))
# print(precision_score(y_test,y_pred3))
# print(confusion_matrix(y_test,y_pred3))

# %% [markdown]
# 1. Using TFIDF object

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
# max _ features  is for improve the  model
tfidf = TfidfVectorizer(max_features=3000)

x =tfidf.fit_transform(df['transform_text']).toarray()
x.shape
# Out:
# (5169, 3000)

# %%
y =df['target'].values
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=2)

# %%
gnb.fit(x_train,y_train)
y_pred1 = gnb.predict(x_test)
print(accuracy_score(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
# Out:
# 0.8694390715667312
# 0.5068493150684932
# [[788 108]
#  [ 27 111]]

# %%
bnb.fit(x_train,y_train)
y_pred3 = bnb.predict(x_test)
print(accuracy_score(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
# Out:
# 0.9835589941972921
# 0.991869918699187
# [[895   1]
#  [ 16 122]]

# %% [markdown]
# # Selct this because precision score is 1

# %%
mnb.fit(x_train,y_train)
y_pred2 = mnb.predict(x_test)
print(accuracy_score(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
# Out:
# 0.9709864603481625
# 1.0
# [[896   0]
#  [ 30 108]]

# %% [markdown]
# # improve MNB with TFIDF

# %%
# set the max_features = 3000

# %% [markdown]
# # Create Pipeline
# # sve the model

# %%
# import pickle
# pickle.dump(tfidf,open('vectorizer.pkl','wb'))
# pickle.dump(mnb,open('model.pkl','wb'))

# %%
import joblib

# # Save the model
joblib.dump(mnb, "model.joblib")

print("Model saved successfully!")
# Out:
# Model saved successfully!
